# %%
import cv2
img=cv2.imread("/content/family.jpg",1)
print(img)
# Out:
# [[[ 86  70 117]
#   [ 87  71 119]
#   [ 87  70 127]
#   ...
#   [  1  14   0]
#   [  7  14   7]
#   [ 10  13  11]]
#
#  [[ 87  71 118]
#   [ 88  72 120]
#   [ 88  71 128]
#   ...
#   [  1  19   0]
#   [  5  16   0]
#   [  8  16   5]]
#
#  [[ 87  71 118]
#   [ 89  73 121]
#   [ 88  71 128]
#   ...
#   [  3  30   0]
#   [  2  23   0]
#   [  6  24   0]]
#
#  ...
#
#  [[ 72 132 148]
#   [ 66 126 142]
#   [ 59 119 135]
#   ...
#   [ 17  35  52]
#   [ 34  50  66]
#   [ 48  65  78]]
#
#  [[ 65 127 143]
#   [ 63 125 141]
#   [ 58 120 136]
#   ...
#   [ 17  38  53]
#   [ 43  63  74]
#   [ 61  81  92]]
#
#  [[ 60 122 138]
#   [ 60 122 138]
#   [ 57 119 135]
#   ...
#   [ 18  40  52]
#   [ 48  68  79]
#   [ 68  89  97]]]

# %%
print(img.shape)
# Out:
# (960, 1280, 3)

# %%
resized=cv2.resize(img,(int(img.shape[1]/2),int(img.shape[0]/2)))
cv2_imshow(resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F05701BE9B0>

# %%
import cv2
face_cascade=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
img=cv2.imread("/content/family.jpg",1)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(gray,1.3,5)
for (x,y,w,h) in faces:
  img=cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)
  resized=cv2.resize(img,(int(img.shape[1]/2),int(img.shape[0]/2)))
cv2_imshow(resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F05700B3940>
